# %%
#수학 라이브러리
import math

print(math.sqrt(16)) #제곱근
# Out:
# 4.0

# %%
# CSV 파일 모듈
# CSV(엑셀) 파일을 읽고 쓰는 모듈
# 데이터 저장/분석 기초에 사용

import csv

# CSV 파일에 한 줄 데이터를 저장
with open('test.csv', 'w', newline='') as f:
    csv.writer(f).writerow(['name', 'score'])
