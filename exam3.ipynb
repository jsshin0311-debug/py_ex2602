# %%
#클로저: 안쪽 함수가 바깥 변수 값을 기억하는 구조

def outer():






def make_plus(x):
    def plus(n):
        return x+n 
    return plus

rs = make_plus(3)

print(rs(5))
print(rs(10))
# Out:
#   Cell In[1], line 11
#     def make_plus(x):
#     ^
# IndentationError: expected an indented block after function definition on line 4

# %%
#데코레이터

def deco(fun):
    def wrap():
        print('실행 전')
